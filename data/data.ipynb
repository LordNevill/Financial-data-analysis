# %% [markdown]
# ### Import libraries

# %%
import datetime as dt
import yfinance as yf
import pandas as pd
from pandas_datareader import data as pdr

# %% [markdown]
# ## Step 1 : Specify the range for data extraction

# %%
end = dt.datetime.now()      
start = dt.datetime(2010, 1, 1)
start, end
# Out:
# (datetime.datetime(2010, 1, 1, 0, 0),
#  datetime.datetime(2025, 11, 8, 16, 51, 1, 360469))

# %% [markdown]
# ## Step 2 : Select the stocks that we want to analize

# %%
stocks = ["AAPL", "MSFT", "META", "AMZN", "TSLA", "GOOGL" ]

# %% [markdown]
# ### Import data

# %%
df = yf.download(stocks, start = start, end = end)

df.head()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_24744\4080279211.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stocks, start = start, end = end)
# [*********************100%***********************]  6 of 6 completed
# Price          Close                                              High  \
# Ticker          AAPL    AMZN      GOOGL META       MSFT TSLA      AAPL
# Date
# 2010-01-04  6.424604  6.6950  15.576999  NaN  23.173344  NaN  6.439314
# 2010-01-05  6.435712  6.7345  15.508402  NaN  23.180836  NaN  6.472036
# 2010-01-06  6.333345  6.6125  15.117456  NaN  23.038572  NaN  6.461231
# 2010-01-07  6.321637  6.5000  14.765529  NaN  22.798981  NaN  6.364266
# 2010-01-08  6.363665  6.6760  14.962370  NaN  22.956209  NaN  6.364265
#
# Price                               ...       Open                       \
# Ticker        AMZN      GOOGL META  ...      GOOGL META       MSFT TSLA
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2025-10-27', '2025-10-28', '2025-10-29', '2025-10-30',
#                '2025-10-31', '2025-11-03', '2025-11-04', '2025-11-05',
#                '2025-11-06', '2025-11-07'],
#               dtype='datetime64[ns]', name='Date', length=3988, freq=None)

# %%
df.columns
# Out:
# MultiIndex([( 'Close',  'AAPL'),
#             ( 'Close',  'AMZN'),
#             ( 'Close', 'GOOGL'),
#             ( 'Close',  'META'),
#             ( 'Close',  'MSFT'),
#             ( 'Close',  'TSLA'),
#             (  'High',  'AAPL'),
#             (  'High',  'AMZN'),
#             (  'High', 'GOOGL'),
#             (  'High',  'META'),
#             (  'High',  'MSFT'),
#             (  'High',  'TSLA'),
#             (   'Low',  'AAPL'),
#             (   'Low',  'AMZN'),
#             (   'Low', 'GOOGL'),
#             (   'Low',  'META'),
#             (   'Low',  'MSFT'),
#             (   'Low',  'TSLA'),
#             (  'Open',  'AAPL'),
#             (  'Open',  'AMZN'),
#             (  'Open', 'GOOGL'),
#             (  'Open',  'META'),
#             (  'Open',  'MSFT'),
#             (  'Open',  'TSLA'),
#             ('Volume',  'AAPL'),
#             ('Volume',  'AMZN'),
#             ('Volume', 'GOOGL'),
#             ('Volume',  'META'),
# ...

# %%
df.columns
# Out:
# MultiIndex([( 'Close',  'AAPL'),
#             ( 'Close',  'AMZN'),
#             ( 'Close', 'GOOGL'),
#             ( 'Close',  'META'),
#             ( 'Close',  'MSFT'),
#             ( 'Close',  'TSLA'),
#             (  'High',  'AAPL'),
#             (  'High',  'AMZN'),
#             (  'High', 'GOOGL'),
#             (  'High',  'META'),
#             (  'High',  'MSFT'),
#             (  'High',  'TSLA'),
#             (   'Low',  'AAPL'),
#             (   'Low',  'AMZN'),
#             (   'Low', 'GOOGL'),
#             (   'Low',  'META'),
#             (   'Low',  'MSFT'),
#             (   'Low',  'TSLA'),
#             (  'Open',  'AAPL'),
#             (  'Open',  'AMZN'),
#             (  'Open', 'GOOGL'),
#             (  'Open',  'META'),
#             (  'Open',  'MSFT'),
#             (  'Open',  'TSLA'),
#             ('Volume',  'AAPL'),
#             ('Volume',  'AMZN'),
#             ('Volume', 'GOOGL'),
#             ('Volume',  'META'),
# ...

# %%
df.to_csv("data.csv")

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
# ...
